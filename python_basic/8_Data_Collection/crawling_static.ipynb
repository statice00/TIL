# %% [markdown]
# 1. 크롤러(crawler)
#    - 자동으로 웹 페이지에 있는 정보를 수집하는 프로그램이다.
#    - 크롤러를 다른 이름으로 ‘봇', '로봇’, ‘스파이더’라 부른다.
#    - 크롤러로 정기적으로 웹 사이트를 돌며 정보를 수집하는 작업을 ‘크롤링(crawling)‘
#     또는 ‘스파이더링(spidering)’이라   한다.
#    - 구글 등의 검색 엔진은 봇 크롤러를 사용해 전 세계에 있는 웹 페이지의 정보를 모아서
#     축적한다. 그리고 사용자가 키워드를 검색하면 축적된  방대한 정보에서 적당한 웹페이지를 찾아 제공해 준다.
#
#
# 2. 스크레이핑(scraping)
#    - 크롤러는 정보를 수집한다.
#    - 스크레이핑은 수집한 정보를 분석해서 필요한 정보를 추출하는 기술을 의미한다.
#    - 예를 들어 전자상거래 사이트 웹 페이지를 크롤러로 내려받는 것이고, 그렇게 내려받은
#      웹 페이지에서 상품명과 가격 등 필요한 정보를 추출하는 것을 스크레이핑이라 부른다.
#
#
# 3. 파이썬에서 http request를 다루는 모듈-url에서 html소스가져오기
#   - urllib 모듈  : 파이썬의 내장 모듈
#   - requests 모듈 : 외부 모듈
#
#
# 4.  Python에서 스파이더링
#    - BeautifulSoup
#      - HTML과 XML 문서의 parsing을 하기 위한 Python 패키지이므로 이 라이브러리를 이용해 우리는 정보를 추출한다.
#
#
#    - Selenium
#      -  "Web Application의 테스트를 자동화하기위한 도구이다.
# Selenium에서는 우리가 웹브라우져를 실행 시킨후 무언가를 클릭하거나,텍스트를 입력하고, 지우는 등의 조작에 해당하는 메소드를 지원한다.
# 팝업을 닫아줘야만 정상적으로 화면을 볼 수 있는 웹사이트도 있다. 그리고 사용하는 이유중 가장 중요한게 바로 동적페이지(JavaScript)로 제공되는 HTML인 경우이다. 이러한 동적페이지의 경우 HTML을 Client에 제공하고 화면에 각 요소들을 뿌려주는 형태로 단순히 BeautifulSoup만 사용했을 때, 찾는 element가 나오지 않을 수도 있다. 이런 경우에 selenium을 통해 제어할 수 있다.
# 실제 크롤링 하는 도구는 BeautifulSoup이지만, 제어해주는 도구가 selenium 이다.
# https://www.selenium.dev/documentation/ko/webdriver/
#
#      - !pip install selenium
#      - chromedriver.exe 다운로드 https://chromedriver.chromium.org/downloads

# %% [markdown]
# 데이터 수집을 위한 기초 문법

# %%
# tag   태그  <ul></ul> <li></li> <div></div> <a></a> => <a />
# property  속성 class, id, href, title, src
# property value 속성값 class="greet"에서 greet이 속성값
# <a href="www.google.com">구글</a> 태그와 속성값은 각각 무엇일까요?
# tag? a, property(속성) href, 속성값 of href : www.google.com
# html <html></html>

# %% [markdown]
# ## urllib 모듈

# %%
import urllib.request
from urllib.request import urlopen

url = 'https://www.naver.com'
html = urlopen(url)

print(type(html)) 
print(dir(html)) # 제공되는 자원 확인
# Out:
# <class 'http.client.HTTPResponse'>
# ...

# %%
# 제공되는 자원중 read() 활용해 읽어온다
print(html.read())

# %% [markdown]
# status : 응답코드 200이 나와야 정상적으로 응답을 받았다는 뜻이다.

# %%
print(html.status)
# Out:
# 200

# %% [markdown]
# 작업공간에 html파일로 저장

# %%
# 파일 열면 naver페이지로 이동
urllib.request.urlretrieve(url, './urllib_naver.html')
# Out:
# ('./urllib_naver.html', <http.client.HTTPMessage at 0x21472ecf220>)

# %% [markdown]
# ## requests 모듈

# %%
import requests

url = 'https://www.naver.com'
cont = requests.get(url)
print(cont)
print(type(cont))
# Out:
# <Response [200]>
# <class 'requests.models.Response'>

# %% [markdown]
# 제공되는 자원 확인

# %%
print(dir(cont))
# Out:
# ['__attrs__', '__bool__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_content', '_content_consumed', '_next', 'apparent_encoding', 'close', 'connection', 'content', 'cookies', 'elapsed', 'encoding', 'headers', 'history', 'is_permanent_redirect', 'is_redirect', 'iter_content', 'iter_lines', 'json', 'links', 'next', 'ok', 'raise_for_status', 'raw', 'reason', 'request', 'status_code', 'text', 'url']

# %% [markdown]
# 상태값만 가지고 와 정상응답인지 확인

# %%
print(cont.status_code)
# Out:
# 200

# %% [markdown]
# ### - text
#     string 자료형으로 반환

# %%
print(cont.text)

# %% [markdown]
# ### - content
#     byte 자료형으로 반환

# %%
print(cont.content)

# %% [markdown]
# ## BeautifulSoup
#
# BeautifulSoup(parsing할 데이터. parsing방법)

# %%
import requests
import bs4

url = 'https://www.naver.com'
res = requests.get(url)
bs_obj = bs4.BeautifulSoup(res.text) # string

# %%
print(type(bs_obj))
print('-----------------------------')
print(bs_obj.find('div'))
# Out:
# <class 'bs4.BeautifulSoup'>
# -----------------------------
# <div id="u_skip"> <a href="#newsstand"><span>뉴스스탠드 바로가기</span></a> <a href="#themecast"><span>주제별캐스트 바로가기</span></a> <a href="#timesquare"><span>타임스퀘어 바로가기</span></a> <a href="#shopcast"><span>쇼핑캐스트 바로가기</span></a> <a href="#account"><span>로그인 바로가기</span></a> </div>

# %% [markdown]
# ### - html.paser
#     html로 파싱

# %%
bs_obj2 = bs4.BeautifulSoup(res.text, 'html.parser')
print(type(bs_obj2))
print('-----------------------------')      
print(bs_obj2.find('div'))
# Out:
# <class 'bs4.BeautifulSoup'>
# -----------------------------
# <div id="u_skip"> <a href="#newsstand"><span>뉴스스탠드 바로가기</span></a> <a href="#themecast"><span>주제별캐스트 바로가기</span></a> <a href="#timesquare"><span>타임스퀘어 바로가기</span></a> <a href="#shopcast"><span>쇼핑캐스트 바로가기</span></a> <a href="#account"><span>로그인 바로가기</span></a> </div>

# %% [markdown]
# ### - lxml
#     html로 파싱. 속도 더 빨라 주로 사용
#     pip install lxml 필요하지만 conda에 이미 설치되어있음

# %%
bs_obj3 = bs4.BeautifulSoup(res.text, 'lxml')
print(type(bs_obj3))
print('-----------------------------')      
print(bs_obj3.find('div'))
# Out:
# <class 'bs4.BeautifulSoup'>
# -----------------------------
# <div id="u_skip"> <a href="#newsstand"><span>뉴스스탠드 바로가기</span></a> <a href="#themecast"><span>주제별캐스트 바로가기</span></a> <a href="#timesquare"><span>타임스퀘어 바로가기</span></a> <a href="#shopcast"><span>쇼핑캐스트 바로가기</span></a> <a href="#account"><span>로그인 바로가기</span></a> </div>

# %% [markdown]
# ### - .find()

# %%
import bs4

html_str = '<html><div>Hello</div></html>'
bs_obj = bs4.BeautifulSoup(html_str, 'lxml')

print(bs_obj.find('div'))
print(bs_obj.find('div').text)
# Out:
# <div>Hello</div>
# Hello

# %%
import bs4

html_str = """
<html>
    <body>
        <ul>
            <li>hello</li>
            <li>bye</li>
            <li>welcome</li>
        </ul>
    </body>
</html>
"""

bs_obj = bs4.BeautifulSoup(html_str, 'lxml')

ul = bs_obj.find('ul')
print(ul)

print('--------------')

ul_li = ul.find('li')
print(ul_li)
print(ul_li.text)
# Out:
# <ul>
# <li>hello</li>
# <li>bye</li>
# <li>welcome</li>
# </ul>
# --------------
# <li>hello</li>
# hello

# %% [markdown]
# ### - find_all()
#     list로 리턴
#
#     BeautifulSoup 3까지는 findAll() 로 사용했었음

# %%
import bs4

html_str = """
<html>
    <body>
        <ul>
            <li>hello</li>
            <li>bye</li>
            <li>welcome</li>
        </ul>
    </body>
</html>
"""

bs_obj = bs4.BeautifulSoup(html_str, 'lxml')

ul = bs_obj.find('ul')
ul_li = ul.find_all('li')
print(ul_li) # list로 리턴
print(ul_li[0]) # 인덱싱 가능

print('----------------')

for element in ul_li :
    print(element.text)
# Out:
# [<li>hello</li>, <li>bye</li>, <li>welcome</li>]
# <li>hello</li>
# ----------------
# hello
# bye
# welcome

# %% [markdown]
# ### - 데이터 추출 시 class 속성 이용
#     -  tag_and_property
#     데이터 추출 시 class 속성 이용
#     find(대상, 찾을 값 dictionary로 지정)
#
#     속성값, class 동시 추출 시

# %%
import bs4

html_str = """
<html>
    <body>
        <ul class="greet">
            <li>hello</li>
            <li>bye</li>
            <li>welcome</li>
        </ul> 
        <ul class="reply">
            <li>ok</li>
            <li>no</li>
            <li>sure</li>
        </ul>
    </body>
</html>
"""

bs_obj = bs4.BeautifulSoup(html_str, 'lxml')
ul_reply1 = bs_obj.find('ul') # 제일 먼저 찾은걸 가져옴
print(ul_reply1)

print('---------------')

bs_obj = bs4.BeautifulSoup(html_str, 'lxml')
ul_reply2 = bs_obj.find('ul', {'class':'reply'}) # 속성값, class 동시 추출 시
print(ul_reply2)

print('---------------')

ul_li = ul_reply2.find_all('li')

for li in ul_li :
    print(li.text)
# Out:
# <ul class="greet">
# <li>hello</li>
# <li>bye</li>
# <li>welcome</li>
# </ul>
# ---------------
# <ul class="reply">
# <li>ok</li>
# <li>no</li>
# <li>sure</li>
# </ul>
# ---------------
# ok
# no
# sure

# %% [markdown]
# ### - 속성값 뽑아내기 property

# %%
import bs4

html_str = """
<html>
    <body>
        <ul class="ko">
            <li>
                <a href="https://www.naver.com/">네이버</a>
            </li>
            <li>
                <a href="https://www.daum.net/">다음</a>
            </li>
        </ul>
        <ul class="sns">
            <li>
                <a href="https://www.google.com/">구글</a>
            </li>
            <li>
                <a href="https://www.facebook.com/">페이스북</a>
            </li>
        </ul>
    </body>
</html>
"""

bs_obj = bs4.BeautifulSoup(html_str, 'lxml')
atag = bs_obj.find('a')
print(atag)
print(atag['href'])
# Out:
# <a href="https://www.naver.com/">네이버</a>
# https://www.naver.com/

# %%
import bs4

html_str = """
<html>
    <body>
        <ul class="ko">
            <li>
                <a href="https://www.naver.com/">네이버</a>
            </li>
            <li>
                <a href="https://www.daum.net/">다음</a>
            </li>
        </ul>
        <ul class="sns">
            <li>
                <a href="https://www.google.com/">구글</a>
            </li>
            <li>
                <a href="https://www.facebook.com/">페이스북</a>
            </li>
        </ul>
        <div id="result"> page </div>
    </body>
</html>
"""

bs_obj = bs4.BeautifulSoup(html_str, 'lxml')
atag = bs_obj.find_all('a')
print(atag)

print('--------------------------')

for attr in atag :
    print(attr['href'])
# Out:
# [<a href="https://www.naver.com/">네이버</a>, <a href="https://www.daum.net/">다음</a>, <a href="https://www.google.com/">구글</a>, <a href="https://www.facebook.com/">페이스북</a>]
# --------------------------
# https://www.naver.com/
# https://www.daum.net/
# https://www.google.com/
# https://www.facebook.com/

# %%
# 속성만 가져올때
dv = bs_obj.find(id = 'result')
print(dv)
# Out:
# <div id="result"> page </div>

# %%
# 속성, 클래스 가져올때
#uclass = bs_obj.find(class_='ko')
uclass = bs_obj.find(True,{'class':'ko'})
print(uclass)
# Out:
# <ul class="ko">
# <li>
# <a href="https://www.naver.com/">네이버</a>
# </li>
# <li>
# <a href="https://www.daum.net/">다음</a>
# </li>
# </ul>

# %%
# 하나의 요소 가져옴
print(bs_obj.find('a'))
print(bs_obj.a)

# 값 가져옴
print(bs_obj.find('a').get_text())
print(bs_obj.a.get_text())
# Out:
# <a href="https://www.naver.com/">네이버</a>
# <a href="https://www.naver.com/">네이버</a>
# 네이버
# 네이버

# %%
# 요소 모두 가져오기
print(bs_obj.find_all('a')) 

# 인덱스 지정해서 가져오기
print(bs_obj.find_all('a')[1].get_text()) 

# 타입 다른거 주의
print(type(bs_obj.find_all('a')))
print(type(bs_obj.a))
# Out:
# [<a href="https://www.naver.com/">네이버</a>, <a href="https://www.daum.net/">다음</a>, <a href="https://www.google.com/">구글</a>, <a href="https://www.facebook.com/">페이스북</a>]
# 다음
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.Tag'>

# %%
# attribute
print(bs_obj.a.attrs)
print(bs_obj.find('a').attrs)
print(bs_obj.a['href'])
print(bs_obj.a.attrs['href'])
print(bs_obj.a.get('href'))
# Out:
# {'href': 'https://www.naver.com/'}
# {'href': 'https://www.naver.com/'}
# https://www.naver.com/
# https://www.naver.com/
# https://www.naver.com/

# %%
# 자식(childern) 확인

print(bs_obj.ul.children)  # list_iterator로 가지고 온다

for sub in bs_obj.ul.children:
    print(sub)
    

    print('----------------------------')
# 인덱싱하려면 find_all()로 가져와서 처리
for sub in bs_obj.find_all('ul')[1].children:
    print(sub)
# Out:
# ...
#
#
# ----------------------------
# <li>
# <a href="https://www.naver.com/">네이버</a>
# </li>
# ----------------------------
#
#
# ----------------------------
# <li>
# <a href="https://www.daum.net/">다음</a>
# </li>
# ----------------------------
#
#
# ----------------------------
#
#
# <li>
# <a href="https://www.google.com/">구글</a>
# </li>
#
#
# <li>
# <a href="https://www.facebook.com/">페이스북</a>
# </li>

# %%
# siblings
print(bs_obj.find('a').next_siblings)
ele = bs_obj.find('a').next_siblings
next(ele) # generator는 next로 가져올 수 있음

print(bs_obj.find('a').previous_siblings)
ele = bs_obj.find('a').previous_siblings
next(ele)
# Out:
# <generator object PageElement.next_siblings at 0x00000214749CA3C0>
# <generator object PageElement.previous_siblings at 0x00000214749CAF90>
# '\n'

# %% [markdown]
# 정규표현식, 람다를 활용가능

# %%
import re

print(bs_obj.find('a', {'href':'https://www.naver.com/'}))

print('------------------------------')

print(bs_obj.find('a', {'href':re.compile('.*com/')}))
print(bs_obj.find('a', {'href':re.compile('.*naver.*')}))
print(bs_obj.find('a', {'href':re.compile('naver')}))

print('------------------------------')

print(bs_obj.find_all('a', {'href':re.compile('.*com/')}))
print(bs_obj.find_all('a', {'href':re.compile('.*naver.*')}))
print(bs_obj.find_all('a', {'href':re.compile('naver')}))

print('------------------------------')

print(bs_obj.find(href=lambda val: val))
print(bs_obj.find(href=lambda val: val and 'naver' in val))

print('------------------------------')

print(bs_obj.find(class_=lambda val: val))
print(bs_obj.find(class_=lambda val: val and 'sns' in val))
# Out:
# <a href="https://www.naver.com/">네이버</a>
# ------------------------------
# <a href="https://www.naver.com/">네이버</a>
# <a href="https://www.naver.com/">네이버</a>
# <a href="https://www.naver.com/">네이버</a>
# ------------------------------
# [<a href="https://www.naver.com/">네이버</a>, <a href="https://www.google.com/">구글</a>, <a href="https://www.facebook.com/">페이스북</a>]
# [<a href="https://www.naver.com/">네이버</a>]
# [<a href="https://www.naver.com/">네이버</a>]
# ------------------------------
# <a href="https://www.naver.com/">네이버</a>
# <a href="https://www.naver.com/">네이버</a>
# ------------------------------
# <ul class="ko">
# <li>
# <a href="https://www.naver.com/">네이버</a>
# </li>
# <li>
# <a href="https://www.daum.net/">다음</a>
# </li>
# </ul>
# <ul class="sns">
# <li>
# <a href="https://www.google.com/">구글</a>
# </li>
# <li>
# <a href="https://www.facebook.com/">페이스북</a>
# </li>
# </ul>

# %% [markdown]
# ### - select_one()
#     find()에서는 못하는 css 셀렉터 지정방식 사용가능

# %%
import bs4

html_str = """
<html>
    <body>
        <ul class="ko">
            <li>
                <a href="https://www.naver.com/">네이버</a>
            </li>
            <li>
                <a href="https://www.daum.net/">다음</a>
            </li>
        </ul>
        <ul class="sns">
            <li>
                <a href="https://www.google.com/">구글</a>
            </li>
            <li>
                <a href="https://www.facebook.com/">페이스북</a>
            </li>
        </ul> 
        <div id="result"> page </div>
    </body>
</html>
"""

bs_obj = bs4.BeautifulSoup(html_str, 'lxml')

ul = bs_obj.select_one('ul')
print(ul)

print('-----------------------')

# 제일 처음 검색된 <li> 가져옴
ul_li = bs_obj.select_one('ul>li')  # css 셀렉터 사용해 검색
print(ul_li)
# Out:
# <ul class="ko">
# <li>
# <a href="https://www.naver.com/">네이버</a>
# </li>
# <li>
# <a href="https://www.daum.net/">다음</a>
# </li>
# </ul>
# -----------------------
# <li>
# <a href="https://www.naver.com/">네이버</a>
# </li>

# %%
bs_obj.select('a')
# Out:
# [<a href="https://www.naver.com/">네이버</a>,
#  <a href="https://www.daum.net/">다음</a>,
#  <a href="https://www.google.com/">구글</a>,
#  <a href="https://www.facebook.com/">페이스북</a>]

# %%
bs_obj.select('.ko')
# Out:
# [<ul class="ko">
#  <li>
#  <a href="https://www.naver.com/">네이버</a>
#  </li>
#  <li>
#  <a href="https://www.daum.net/">다음</a>
#  </li>
#  </ul>]

# %%
# find_all 과 매치
bs_obj.select('#result')
# Out:
# [<div id="result"> page </div>]

# %%
# find 와 매치
bs_obj.select_one('#result')
# Out:
# <div id="result"> page </div>

# %%
bs_obj.select('ul.sns > li:nth-of-type(2)')
# Out:
# [<li>
#  <a href="https://www.facebook.com/">페이스북</a>
#  </li>]

# %%
ul_li = bs_obj.select('ul>li')
print(ul_li)

print('-----------------------')

for liElement in ul_li :
    #print(dir(liElement))
    #print(liElement)
    print(liElement.text)
# Out:
# [<li>
# <a href="https://www.naver.com/">네이버</a>
# </li>, <li>
# <a href="https://www.daum.net/">다음</a>
# </li>, <li>
# <a href="https://www.google.com/">구글</a>
# </li>, <li>
# <a href="https://www.facebook.com/">페이스북</a>
# </li>]
# -----------------------
#
# 네이버
#
#
# 다음
#
#
# 구글
#
#
# 페이스북

# %%
print(bs_obj.select_one('a'))
print(type(bs_obj.select_one('a')))  # find('a')와 타입이 같음
print(type(bs_obj.select('a')))      # find_all('a')와 타입이 같음
# Out:
# <a href="https://www.naver.com/">네이버</a>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.ResultSet'>

# %% [markdown]
# ## 응답코드가 400번대일때 해결방법
#
# 웹 url을 통해서 데이터를 가져올때 유저 에이전트 헤더를 검사한다
#
# - requests.get(url, headers = header)
#
#     urlopen() 은 headers가 인자로 없지만, requests.get은 인자로 있어서 사용가능
#
#
# - User-Agent 확인하는 법 : F12를 눌러 개발자 모드 - Console 탭으로 이동 - 이동한 후에, 하단 부에 명령어 입력부에 navigator.userAgent라고 입력
#     또는 ctrl + r 누른 후 좌측Name에서 해당페이지 클릭 - Headers -  맨아래로 가면 user-agent 있음

# %%
import bs4
import requests

# Http Error 406 : Not Acceptable
# <Response [406]> -> <Response [200]>
url = 'https://www.melon.com/'
header = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.114 Safari/537.36"}

res = requests.get(url, headers = header)
print(res) 

print('--------------------------')

bs_melon = bs4.BeautifulSoup(res.text, 'lxml')
print(bs_melon)
# Out:
# <Response [200]>
# --------------------------
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>Melon::음악이 필요한 순간, 멜론</title>
# <meta content="음악서비스, 멜론차트, 멜론TOP100, 최신음악, 인기가요, 뮤직비디오, 앨범, 플레이어, 스트리밍, 다운로드, 아티스트플러스, 아티스트채널" name="keywords"/>
# <meta content="국내 최다 4,000만곡 보유, No.1 뮤직플랫폼 멜론! 최신 트렌드부터 나를 아는 똑똑한 음악추천까지!" name="description"/>
# <meta content="e2b43191afa0f1d2deb8e2cda8f45ee1408c44a1" name="naver-site-verification"/>
# <meta content="357952407588971" property="fb:app_id"/>
# <meta content="Melon" property="og:title"/>
# <meta content="https://cdnimg.melon.co.kr/resource/image/web/common/logo_melon142x99.png" property="og:image"/>
# <meta content="음악이 필요한 순간, 멜론" property="og:description"/>
# <meta content="http://www.melon.com/" property="og:url"/>
# <meta content="website" property="og:type"/>
# ...

# %% [markdown]
# ## 크롤링 허용 여부 확인하기
#
# - 수집정책 사이트 : http://www.robotstxt.org/
#
# - https://크롤링주소/robots.txt  입력하고 확인
#
#    |표시|허용여부|
#    |:---:|:---:|
#    |User-agent: * | 모든 접근 허용|
#    |Disallow:     ||
#    | 또는         ||
#    |User-agent: * |모든 접근 허용|
#    |Allow: /      ||
#    |User-agent:*  |모든 접근 금지(open API로 접근해야함)|
#    |Disallow:/    ||
#    |User-agent: * |특정 디렉토리(/user/)만 접근 금지|
#    |Disallow: /user/||

# %% [markdown]
# ## GET 방식 request

# %%
def getDownload( url, param = None, retries = 3 ):
    resp = None
    try:
        resp = requests.get( url, params = param )
        resp.raise_for_status()
    except requests.exceptions.HTTPError as e:
        if 500 <= resp.status_code < 600 and retries > 0:
            print( 'Retries : {0}'.format( retries ) )
            return getDownload( url, param, retries - 1 )
        else:
            print( resp.status_code )
            print( resp.reason )
            print( resp.request.headers )
    return resp

# %%
url = 'http://www.crawler-test.com/status_codes/status_500'
getDownload( url )
# Out:
# Retries : 3
# Retries : 2
# Retries : 1
# 500
# Internal Server Error
# {'User-Agent': 'python-requests/2.25.1', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}
# <Response [500]>

# %% [markdown]
# ## POST방식 request

# %%
def postDownload( url, data = None, param = None, retries = 3 ):
    resp = None
    try:
        resp = requests.post( url, data, params = param )
        resp.raise_for_status()
    except requests.exceptions.HTTPError as e:
        if 500 <= resp.status_code < 600 and retries > 0:
            print( 'Retries : {0}'.format( retries ) )
            return postDownload( url, param, retries - 1 )
        else:
            print( resp.status_code )
            print( resp.reason )
            print( resp.request.headers )
    return resp

# %%
url = 'http://pythonscraping.com/pages/files/processing.php'
data = { 'firstname':'테스트', 'lastname':1234 }

# %%
html = postDownload( url, data )
print( html.request.body )
print( '------------------------------' )
print( html.request.headers )
html.text
# Out:
# firstname=%ED%85%8C%EC%8A%A4%ED%8A%B8&lastname=1234
# ------------------------------
# {'User-Agent': 'python-requests/2.25.1', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive', 'Content-Length': '51', 'Content-Type': 'application/x-www-form-urlencoded'}
# 'Hello there, 테스트 1234!'

# %% [markdown]
# ## class속성의 값이 2개 이상일때

# %%
header = {"user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.114 Safari/537.36"}
url = requests.get('https://news.naver.com/', headers = header)
# print(url)  # <Response [200]>

html = bs4.BeautifulSoup(url.text, 'lxml')
# print(html)

newsnow = html.find('ul', {'class':'mlist2 no_bg'}) # 클래스 속성이 하나이든 두개이든 지정하는 방식은 동일. 띄어쓰기로 구분
#print(newsnow)

for new_li in newsnow.find_all('li'):
    #print(new_li)
    new_strong = new_li.find('strong')
    #print(new_strong)
    #print(new_strong.text)
    print(re.findall('[a-z가-힣]+', new_strong.text))
# Out:
# ['국민의힘', '대권', '주자들', '윤석열', '정치', '선언에', '오묘한', '긴장감']
# ['부인', '김건희', '제가', '쥴리', '기가막혀', '지어낸', '소설']
# ['홍준표', '이재명은', '쌍욕하는', '사람', '정세균은', '딱하다']
# ['윤석열', '국민', '약탈', '정권', '주장에', '입장', '없다']
# ['데뷔전', '학점', '못', '미친', '윤석열', '파일', '정면', '돌파로', '승부수']
